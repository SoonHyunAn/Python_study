# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False # -(마이너스) 기호 깨짐 방지

# %%
data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([  89,   14,  -25,   46,    3,  -87, -101, -181, -216, -249, -198,
#        -251, -233, -327, -325, -350, -258, -235, -141,  -66,  -78,  -92,
#        -115, -186, -101,  -79,  -28,  -46, -114, -166,  -74,  -63, -135,
#        -227, -297, -211, -276, -243, -297, -356, -421, -466, -427, -514,
#        -518, -533, -631, -575, -670, -642])

# %%
plt.plot(range(50),data, 'g') # ''는 색 지정
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
print('버전', mpl.__version__)
print('설치 위치', mpl.__file__)
print('설정 위치', mpl.get_configdir())
print('캐시 위치', mpl.get_cachedir())
print('설정 파일 위치', mpl.matplotlib_fname())

# %%
import matplotlib.pyplot as plt
font_list = [f.name for f in fm.fontManager.ttflist]
print(font_list)
plt.rc('font', family='NanumGothic') # For windows 한글 폰트 나눔고딕 적용
# Out:
# ['STIXGeneral', 'STIXNonUnicode', 'DejaVu Sans Mono', 'STIXGeneral', 'cmtt10', 'STIXSizeFourSym', 'DejaVu Sans Mono', 'STIXGeneral', 'DejaVu Serif', 'DejaVu Sans Mono', 'cmex10', 'STIXNonUnicode', 'STIXSizeFiveSym', 'STIXSizeTwoSym', 'cmss10', 'DejaVu Sans Mono', 'STIXSizeOneSym', 'DejaVu Serif Display', 'cmmi10', 'STIXGeneral', 'DejaVu Sans Display', 'STIXNonUnicode', 'DejaVu Serif', 'DejaVu Sans', 'DejaVu Sans', 'STIXSizeThreeSym', 'DejaVu Sans', 'cmr10', 'cmsy10', 'DejaVu Sans', 'STIXNonUnicode', 'DejaVu Serif', 'STIXSizeFourSym', 'STIXSizeOneSym', 'cmb10', 'STIXSizeThreeSym', 'STIXSizeTwoSym', 'DejaVu Serif', 'Bookman Old Style', 'Tw Cen MT Condensed', 'Monotype Corsiva', 'Cambria', 'Microsoft YaHei', 'Segoe UI', 'Eras Light ITC', 'Vladimir Script', 'Leelawadee', 'Lucida Fax', 'Bodoni MT', 'Jokerman', 'Calisto MT', 'Arial', 'Century Schoolbook', 'Franklin Gothic Demi', 'New Gulim', 'Franklin Gothic Heavy', 'Gill Sans MT', 'Times New Roman', 'Gill Sans MT', 'Century Schoolbook', '
# ...

# %%
font_list = fm.findSystemFonts (fontpaths=None, fontext='ttf')
print(len(font_list))
# Out:
# 384

# %%
font_list[:10]
# Out:
# ['C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\BOD_I.TTF',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\H2MJRE.TTF',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\PLAYBILL.TTF',
#  'C:\\Windows\\Fonts\\ANTQUABI.TTF']

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumGothic', 'C:\\Windows\\Fonts\\NanumGothic.ttf')]

# %%
print(plt.rcParams['font.serif'])
print(plt.rcParams['font.sans-serif'])
print(plt.rcParams['font.monospace'])
# Out:
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %%
# 1
# plt.rcParams["font.family"]='NanumGothic'
# plt.rcParams["font.size"] = 20
# plt.rcParams["figure.figsize"] = (14, 4)

# 2
# path = '폰트 경로'
# font_name = fm.FontProperties (fname=path, size=50).get_name() - 폰트 이름 가져오기
# print(font_name)
# plt.rc('font', family=font_name)

# 3
fig, ax = plt.subplots()
plt.rcParams['font.family'] = 'NanumGothic' #  - 노트북 전체에 지정(비휘발성, 재진행 안해도 됨)
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('숫자 분포도 보기')
plt.show()

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...
